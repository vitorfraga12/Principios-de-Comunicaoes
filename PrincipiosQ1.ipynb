# %%
import numpy as np
import matplotlib.pyplot as plt

amostras = 1000
amp = 1
fc = 5
k = 1.5

s = []
for t in range(amostras):
    m_t = np.cos(2 * np.pi * t / 1000)  # Correção na definição de m_t
    s.append(amp * (1 + m_t * k) * np.cos(2 * np.pi * (t / 1000) * fc))

plt.plot(s)
plt.ylim(-3, 3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

amostras = 1000
amp = 1
fc = 5
k = 1.5

c = []
for t in range(amostras):
    c.append(amp *  np.cos(2 * np.pi * (t / 1000) * fc))

plt.plot(c)
plt.ylim(-3, 3)
plt.show()
